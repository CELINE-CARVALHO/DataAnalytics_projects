# %% [markdown]
# # <span style="color:darkorchid">**INTRODUCTION**</span>

# %% [markdown]
# #### 1. Founded in 1929, MoMA houses a collection of nearly 200,000 works of art spanning 150 years, alongside a variety of visual objects.
# #### 2. The museum’s website contains information on 98,361 works by 27,140 artists, while providing a research database with 140,848 records for               research purposes
# #### 3. MoMA emphasizes transparency, provides data "as is" for research purposes and makes no representations or warranties as to the completeness or          accuracy of the data Users are encouraged to specify understand the information responsibly.

# %% [markdown]
# ***

# %% [markdown]
# # <span style="color:darkorchid">**DISCRIPTION ABOUT THE DATASET**</span>

# %% [markdown]
# #### 1. The dataset contains basic metadata about each work and artist, such as title, artist, date, style, and concepts.
# #### 2. The another data is for 15,243 artists includes information such as name, country of origin, gender, year of birth, year of death, Wiki QID and         Getty Ulan ID.

# %% [markdown]
# ***

# %% [markdown]
# # <span style="color:darkorchid">**PROBLEM STATEMENT AND OBJECTIVE**</span>

# %% [markdown]
# #### 1. Performing a comprehensive Exploratory Data Analysis (EDA) involves examining key variables' distribution, including artists across                  nationalities, genders, and historical periods, aiming to identify skewed distributions, outliers, or unusual patterns.
# #### 2. Analyzing temporal trends unveils insights into art history, art movements, and evolving artistic styles. Correlation analysis delves into           relationships between attributes, such as nationality and artistic medium. Exploring genres and mediums identifies dominant styles and               shifting preferences over time.
# #### 3. Geospatial analysis visualizes artists' and artworks' geographical distribution, uncovering artistic hubs and cultural influences.
# #### 4. Assessing artists' careers and productivity involves analyzing career durations, artwork production, and identifying prolific artists.
# #### 5. Dimension analysis investigates the distribution of artwork dimensions, while examining gender representation uncovers trends in male and            female artist distribution across time and nationalities.
# #### 6. These analyses collectively provide a holistic understanding of the dataset, paving the way for informed decision-making and deeper insights         into the dynamics of the art world.

# %% [markdown]
# ***

# %% [markdown]
# # <span style="color:darkorchid">**RESULT**</span>

# %% [markdown]
# #### 1. Artists' Demographics: The dataset comprises artists from diverse nationalities, genders, and historical periods.
#
# #### 2. Gender distribution across artists reflects both male and female contributions, highlighting inclusivity.
#
# #### 3. Temporal Trends:  Analyzing temporal trends revealed shifts in artistic styles and movements over the years.
#
# #### 4. The temporal distribution of artworks across classifications showcased evolving preferences and enduring styles.
#
# #### 5. A detailed examination of begin dates provided insights into the historical timeline of artists' careers.
#
# #### 6. Geospatial Analysis: Geospatial analysis visualized the geographical distribution of artists, uncovering artistic hubs and cultural influences.
#
# #### 7. While longitude and latitude were not available, alternative approaches could be explored for a more accurate geospatial analysis.
#
# #### 8. Artists' Careers and Productivity:   Assessment of artists' careers and productivity involved analyzing career durations and artwork production.
#
# #### 9. Classification and Medium Analysis:   Classification analysis highlighted dominant artistic genres over the years.
#
# #### 10. Examining the distribution of artworks across mediums provided additional insights into artistic preferences.

# %% [markdown]
# ***

# %% [markdown]
# # <span style="color:darkorchid">**CONCLUSION**</span>

# %% [markdown]
# #### 1. The holistic understanding gained through EDA enables informed decision-making and deeper insights into the dynamics of the art world.
# #### 2. Further exploration and refinement, including detailed geospatial analysis and additional variables, could enhance the depth of insights.
# #### Overall, the analysis provides a nuanced perspective on the dataset, shedding light on the multifaceted nature of the art world and contributing to a richer understanding of its historical and contemporary dimensions."

# %% [markdown]
# ***

# %% [markdown]
# # <span style="color:darkorchid">**REFERANCE**</span>

# %% [markdown]
# 1. https://chat.openai.com/
# 2. https://www.javatpoint.com/library-in-python
# 3. https://pypi.org/project/Markdown/
# 4. https://intellipaat.com/blog/what-is-eda-in-data-science/
# 5. https://www.analyticsvidhya.com/blog/2021/05/exploratory-data-analysis-eda-a-step-by-step-guide/

# %% [markdown]
# ***

# %% [markdown]
# # <span style="color:darkorchid">***Exploratory Data Analysis on the datasets***</span>

# %% [markdown]
# ### <span style="color:darkred">***merging the two data set for the analysis***</span>

# %%
import pandas as pd

try:
    # the two csv files 
    artworks_file_path = 'Artworks.csv'
    artists_file_path = 'Artists.csv'

    # Read the CSV files into pandas DataFrames
    artworks_df = pd.read_csv(artworks_file_path)
    artists_df = pd.read_csv(artists_file_path)

    # Convert the key column to the same data type in both DataFrames
    key_column = ['ConstituentID']
    artworks_df[key_column] = artworks_df[key_column].astype(str)
    artists_df[key_column] = artists_df[key_column].astype(str)

    # Merge DataFrames based on the common key ("ConstituentID")
   
    merged_df = pd.merge(artworks_df, artists_df, on='ConstituentID', how='inner')

    # Save the merged DataFrame to a new CSV file
    merged_df.to_csv('merged_file.csv', index=False)

    print("Files merged successfully!")

except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Files merged successfully!

# %% [markdown]
# ### <span style="color:darkred">***loading all the libraries***</span>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import plotly.express as px

# %% [markdown]
# ### <span style="color:darkred">***understanding the datsset***</span>

# %%
# to read the data 
data = pd.read_csv("merged_file.csv")

# %%
# first five rows and columns are shown
data.head()
# Out:
#                                                Title  \
# 0  Ferdinandsbrücke Project, Vienna, Austria (Ele...
# 1                                           Armchair
# 2                                              Stool
# 3                                            Railing
# 4  City of Music, National Superior Conservatory ...
#
#                      Artist  ConstituentID            ArtistBio_x  \
# 0               Otto Wagner           6210  (Austrian, 1841–1918)
# 1               Otto Wagner           6210  (Austrian, 1841–1918)
# 2               Otto Wagner           6210  (Austrian, 1841–1918)
# 3               Otto Wagner           6210  (Austrian, 1841–1918)
# 4  Christian de Portzamparc           7470    (French, born 1944)
#
#   Nationality_x BeginDate_x EndDate_x Gender_x  Date  \
# 0    (Austrian)      (1841)    (1918)   (Male)  1896
# 1    (Austrian)      (1841)    (1918)   (Male)  1902
# 2    (Austrian)      (1841)    (1918)   (Male)  1904
# ...

# %%
data.tail()   # the last 5 rows and columns are shown
# Out:
#                                  Title            Artist  ConstituentID  \
# 131886                            #nyc  Jeff Mermelstein         132145
# 131887        Half Indian/Half Mexican        James Luna          34698
# 131888              The Execution Room     Mohammed Sami         134817
# 131889                         My Hope     Lauren Halsey         134819
# 131890  Homage to the Hunters of Mandé  Abdoulaye Konaté         135018
#
#                                ArtistBio_x      Nationality_x BeginDate_x  \
# 131886               (American, born 1957)         (American)      (1957)
# 131887  (Payómkawichum/Luiseño, 1950–2018)  (Native American)      (1950)
# 131888                  (Iraqi, born 1984)            (Iraqi)      (1984)
# 131889               (American, born 1987)         (American)      (1987)
# 131890                 (Malian, born 1953)           (Malian)      (1953)
#
#        EndDate_x  Gender_x     Date  \
# 131886       (0)    (Male)     2018
# ...

# %%
data.shape    # shows that we have 156091 rows and 37 coloums
# Out:
# (131891, 37)

# %%
data.columns   # shoes the titles of the colomns
# Out:
# Index(['Title', 'Artist', 'ConstituentID', 'ArtistBio_x', 'Nationality_x',
#        'BeginDate_x', 'EndDate_x', 'Gender_x', 'Date', 'Medium', 'Dimensions',
#        'CreditLine', 'AccessionNumber', 'Classification', 'Department',
#        'DateAcquired', 'Cataloged', 'ObjectID', 'URL', 'ThumbnailURL',
#        'Circumference (cm)', 'Depth (cm)', 'Diameter (cm)', 'Height (cm)',
#        'Length (cm)', 'Weight (kg)', 'Width (cm)', 'Seat Height (cm)',
#        'Duration (sec.)', 'DisplayName', 'ArtistBio_y', 'Nationality_y',
#        'Gender_y', 'BeginDate_y', 'EndDate_y', 'Wiki QID', 'ULAN'],
#       dtype='object')

# %%
data.describe()          # discribes the data
# Out:
#        ConstituentID       ObjectID  Circumference (cm)    Depth (cm)  \
# count  131891.000000  131891.000000            9.000000  13340.000000
# mean     9390.597926  101206.205549           47.242244     15.124735
# std     16266.576847   93723.406306           29.305703     53.568816
# min         1.000000       2.000000            9.900000      0.000000
# 25%      1686.000000   36151.500000           23.500000      0.000000
# 50%      4397.000000   72454.000000           38.000000      0.000000
# 75%      7166.000000  141269.500000           72.000000      7.461265
# max    135298.000000  440440.000000           83.800000   1808.483617
#
#        Diameter (cm)    Height (cm)  Length (cm)    Weight (kg)  \
# count    1332.000000  116356.000000   673.000000     280.000000
# mean       23.242883      37.544786    78.094873    1329.586055
# std        46.686364      49.797787   128.632868   12228.487374
# min         0.635000       0.000000     0.000000       0.090000
# ...

# %%
data.nunique()      # shows the unique values
# Out:
# Title                  93387
# Artist                 11125
# ConstituentID          11163
# ArtistBio_x             6206
# Nationality_x            115
# BeginDate_x              221
# EndDate_x                168
# Gender_x                   7
# Date                    8521
# Medium                 19899
# Dimensions             81522
# CreditLine              6954
# AccessionNumber       131891
# Classification            35
# Department                 8
# DateAcquired            1678
# Cataloged                  2
# ObjectID              131891
# URL                    88580
# ThumbnailURL           78173
# Circumference (cm)         9
# Depth (cm)              1286
# Diameter (cm)            491
# Height (cm)             3782
# Length (cm)              364
# Weight (kg)              199
# Width (cm)              3806
# Seat Height (cm)           0
# Duration (sec.)          602
# DisplayName            11125
# ArtistBio_y             6206
# Nationality_y            114
# ...

# %%
data['Department'].unique()      # shows the unique values that are in the department
# Out:
# array(['Architecture & Design', 'Drawings & Prints',
#        'Architecture & Design - Image Archive', 'Photography',
#        'Painting & Sculpture', 'Film', 'Fluxus Collection',
#        'Media and Performance'], dtype=object)

# %% [markdown]
# ### <span style="color:darkred">***cleaning the dataset***</span>

# %%
data.isnull().sum()
# Out:
# Title                     21
# Artist                     0
# ConstituentID              0
# ArtistBio_x             4483
# Nationality_x              0
# BeginDate_x                0
# EndDate_x                  0
# Gender_x                   0
# Date                    1477
# Medium                  8811
# Dimensions              8177
# CreditLine              1804
# AccessionNumber            0
# Classification             1
# Department                 0
# DateAcquired            5945
# Cataloged                  0
# ObjectID                   0
# URL                    43311
# ThumbnailURL           53193
# Circumference (cm)    131882
# Depth (cm)            118551
# Diameter (cm)         130559
# Height (cm)            15535
# Length (cm)           131218
# Weight (kg)           131611
# Width (cm)             16366
# Seat Height (cm)      131891
# Duration (sec.)       130218
# DisplayName                0
# ArtistBio_y             4483
# Nationality_y           5006
# ...

# %%
remove_data = data.drop(['Circumference (cm)','Diameter (cm)','Length (cm)','Weight (kg)','Seat Height (cm)','Duration (sec.)','ArtistBio_x','Nationality_x','BeginDate_x','EndDate_x','Gender_x'] , axis = 1)

# %%
# checking if threre are any duplicated value
print(remove_data.duplicated().sum())
# Out:
# 0

# %%
# showing that the coloums are removed
remove_data.head()
# Out:
#                                                Title  \
# 0  Ferdinandsbrücke Project, Vienna, Austria (Ele...
# 1                                           Armchair
# 2                                              Stool
# 3                                            Railing
# 4  City of Music, National Superior Conservatory ...
#
#                      Artist  ConstituentID  Date  \
# 0               Otto Wagner           6210  1896
# 1               Otto Wagner           6210  1902
# 2               Otto Wagner           6210  1904
# 3               Otto Wagner           6210  1899
# 4  Christian de Portzamparc           7470  1987
#
#                                           Medium  \
# 0  Ink and cut-and-pasted painted pages on paper
# 1                        Beech wood and aluminum
# 2  Bent beech wood, molded plywood, and aluminum
# 3                              Painted cast-iron
# 4              Paint and colored pencil on print
#
# ...

# %% [markdown]
# ### <span style="color:darkred">***relationship analysis***</span>

# %% [markdown]
# ### <span style="color:darkred">***Distribution Analysis of Key Variables:***</span>

# %% [markdown]
# ### <span style="color:green">***Artists across nationalities***</span>

# %%
nationality_distribution = remove_data['Nationality_y'].value_counts()
nationality_distribution.plot(kind='pie', autopct='%1.1f%%', figsize=(10, 8), title='Artists Distribution Across Nationalities')
plt.ylabel('')
plt.show()

# %% [markdown]
# #### the pie chart shows the number of artists from different nationalities, the percentage of artworks contributed by each nationality
# #### The museum collection exhibits a clear dominance of America artists, comprising 46% of the total, reflecting the historical and cultural influences that shaped its acquisitions.

# %%
top_nationalities = remove_data['Nationality_y'].value_counts().head(50).index
top_nationalities_data = remove_data[remove_data['Nationality_y'].isin(top_nationalities)]

# Creating  a horizontal bar plot
plt.figure(figsize=(12, 10))
sns.countplot(y='Nationality_y', data=top_nationalities_data, palette='viridis')

# labeling the plot appearance
plt.xlabel('Count')
plt.ylabel('Nationality')
plt.title('Distribution of Artists Across Top 20 Nationalities')

# Display the plot
plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_9944\2334796272.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y='Nationality_y', data=top_nationalities_data, palette='viridis')

# %% [markdown]
# #### The horizontal bar plot illustrates the distribution of artists across the top 20 nationalities in the dataset. America appears to be the most prominently represented, followed by French and German. This insight into the distribution provides valuable information about the diverse origins of artists within the dataset, highlighting the global nature of artistic contributions.

# %% [markdown]
# ### <span style="color:green">***Artists across genders***</span>

# %%
gender_distribution = remove_data['Gender_y'].value_counts()
gender_distribution.plot(kind='pie', autopct='%1.1f%%', title='Gender Distribution of Artists')
plt.show()

# %% [markdown]
# #### The data reveals a significant underrepresentation of Female artists in the field of art , with only 84% identifying as such, highlighting potential gender disparities within the industry.

# %% [markdown]
# ### <span style="color:green">***artists across the years***</span>

# %%
remove_data['Date'] = pd.to_datetime(remove_data['Date'], errors='coerce')  # errors='coerce' argument handles any conversion errors by replacing them with NaN

# Plotting the histogram
plt.hist(remove_data['Date'].dropna(), bins=40, color='skyblue', edgecolor='black')
plt.title('Number of Artists by the year')
plt.xlabel('the year of the beggining')
plt.ylabel('Number of Artists')
plt.show()

# %% [markdown]
# #### 1970 stands out with more than 12000 artists contributed in the artworks, suggesting that through the year there may a less contribution to the art and less of artist

# %% [markdown]
# ### <span style="color:darkred">***Temporal Trends and Correlation Analysis:***</span>

# %% [markdown]
# #### <span style="color:green">***We'll visualize the temporal trends by plotting the number of artworks created each year and explore the classification in which factor(Architecture,Design).***</span>

# %%
remove_data['Year'] = pd.to_datetime(remove_data['BeginDate_y']).dt.year

# Get counts of each classification for each year
category_counts_per_year = remove_data.groupby(['Year', 'Classification']).size().reset_index(name='Count')

# Create a bar graph
plt.figure(figsize=(14, 8))
sns.barplot(x='Classification', y='Count', hue='Year', data=category_counts_per_year, palette='viridis')
plt.xticks(rotation=90, ha='right')

# Add labels and title
plt.xlabel('Classification')
plt.ylabel('Number of Artworks')
plt.title('Bar Graph of Classification Counts Over the Years')

# Show the plot
plt.legend(title='Year', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %% [markdown]
# #### The bar graph provides a comprehensive view of the distribution of artworks across different classifications over the years. Notably, 1970 stands out with a significant increase in the number of artworks, particularly in the Photograpy. This suggests a trend or shift in artistic preferences during that period. Additionally, the consistent representation of illustrated book across multiple years indicates its enduring popularity. The visualization offers valuable insights into the evolving landscape of artistic classifications, highlighting distinct patterns and trends over the analyzed years.

# %%
category_counts =remove_data['Classification'].value_counts()

# Create a bar graph
plt.bar(category_counts.index, category_counts.values)
plt.xticks(rotation=90, ha='right')
# Add labels and title
plt.xlabel('the sector in artworks MOMA')
plt.ylabel('the no of contribution')
plt.title('Bar Graph of classification')

# Show the plot
plt.show()

# %% [markdown]
# #### The bar graph illustrates the distribution of artworks across various classifications in the MOMA dataset. Photography appears to be the dominant category, contributing significantly more artworks than other classifications. The diversity in artistic expressions is evident, with notable representation in Print(copied from the net or used for the other perpose) and Illustrated book. This visualization provides a succinct overview of the dataset's composition, shedding light on the prevalence of specific artistic genres within the MOMA collection.

# %% [markdown]
# ### <span style="color:darkred">***Assessing artists careers and productivity***</span>

# %% [markdown]
# ### <span style="color:green">***analyzing career durations***</span>

# %% [markdown]
# ### <span style="color:orange">***THE TOP 20 ARTIST THAT CONTRIBUTED TO THE MOMA***</span>

# %%
# Assuming 'Artist' is the column containing artist names
top_contributors = remove_data['Artist'].value_counts()

# Create a horizontal bar plot for all artists
plt.figure(figsize=(12, 8))
sns.barplot(x=top_contributors.head(20), y=top_contributors.head(20).index, palette='viridis')

# Customize plot appearance
plt.xlabel('Number of Artworks')
plt.ylabel('Artist')
plt.title('Top Contributing Artists')

# Display the plot
plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_9944\3926317297.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_contributors.head(20), y=top_contributors.head(20).index, palette='viridis')

# %% [markdown]
# #### The horizontal bar plot showcases the top contributing artists in the dataset based on the number of artworks. Notably, Eugene Atget emerges as the most prolific contributor, creating a substantial body of work within the dataset. Other prominent artists include louise bourgeois and a famous photographer how is unknown indicating their significant impact on the collection. This visualization provides valuable insights into the distribution of artistic contributions, highlighting the noteworthy role of specific artists in shaping the dataset.

# %% [markdown]
# ### <span style="color:darkred">***artist based on the classifcation and birthyear***</span>

# %%
unique_birthdates = remove_data['BeginDate_y'].unique()
print("Unique Birthdates:", unique_birthdates)

# Extract year from 'birthdate'
remove_data['year'] = pd.to_datetime(remove_data['BeginDate_y'], errors='coerce').dt.year

# Create a pivot table for the count of artists based on 'classification' and 'year'
artists_pivot_table = remove_data.pivot_table(index='Classification', columns='year', aggfunc='size', fill_value=0)

# Plot a heatmap to visualize the table
plt.figure(figsize=(14, 8))
sns.heatmap(artists_pivot_table, cmap='Greens', annot=True, fmt='d', cbar_kws={'label': 'Number of Artists'})
plt.title('Number of Artists Based on Classification and Birth Year')
plt.xlabel('Year')
plt.ylabel('Classification')
plt.show()
# Out:
# Unique Birthdates: <DatetimeArray>
# ['1970-01-01 00:00:00.000001841', '1970-01-01 00:00:00.000001944',
#  '1970-01-01 00:00:00.000001876', '1970-01-01 00:00:00.000001901',
#  '1970-01-01 00:00:00.000001878', '1970-01-01 00:00:00.000001869',
#  '1970-01-01 00:00:00.000001933', '1970-01-01 00:00:00.000001949',
#  '1970-01-01 00:00:00.000001934', '1970-01-01 00:00:00.000001886',
#  ...
#  '1970-01-01 00:00:00.000002004', '1970-01-01 00:00:00.000001989',
#  '1970-01-01 00:00:00.000002012', '1970-01-01 00:00:00.000002003',
#  '1970-01-01 00:00:00.000002010', '1970-01-01 00:00:00.000002014',
#  '1970-01-01 00:00:00.000001991', '1970-01-01 00:00:00.000001990',
#  '1970-01-01 00:00:00.000002008', '1970-01-01 00:00:00.000002016']
# Length: 221, dtype: datetime64[ns]

# %% [markdown]
# #### The heatmap provides a comprehensive view of the distribution of artists across different classifications and birth years in the dataset. Noteworthy patterns emerge, with certain classifications experiencing peaks in artist contributions during specific periods. For instance, photographshows a significant increase in the number of artists born in the early 20th century, suggesting a concentration of artistic activity during that era. The heatmap effectively visualizes the interplay between artists' birth years and their respective classifications, offering insights into historical trends and artistic movements within the dataset.

# %% [markdown]
# ### <span style="color:darkred">***THE COUNTRIES AND THE GENGER ANANLYSIS***</span>

# %%
top_nationalities = remove_data['Nationality_y'].value_counts().head(20).index
top_nationalities_data = remove_data[remove_data['Nationality_y'].isin(top_nationalities)]

# Create a horizontal bar plot with hue for gender
plt.figure(figsize=(12, 10))
sns.countplot(y='Nationality_y', data=top_nationalities_data, hue='Gender_y', palette='deep')

# Customize plot appearance
plt.xlabel('Count')
plt.ylabel('Nationality')
plt.title('Distribution of Artists Across Top 50 Nationalities by Gender')

# Display the plot
plt.legend(title='Gender', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %% [markdown]
# #### The horizontal bar plot provides insights into the distribution of artists across the top 20 nationalities, further stratified by gender. Notably, American exhibits a diverse representation of both male and female artists, suggesting a balanced contribution from both genders. Conversely, French shows a notable gender disparity, with a higher representation of Male. This visualization offers a nuanced perspective on the intersection of nationality and gender within the dataset, revealing patterns that may reflect broader trends in the art world

# %% [markdown]
# ### <span style="color:darkred">***Artists' Careers***</span>

# %% [markdown]
# ### <span style="color:green">***Artists'Analyzing career duration in the years***</span>

# %%
remove_data['BeginDate_y'] = pd.to_datetime(remove_data['BeginDate_y'])
remove_data['EndDate_y'] = pd.to_datetime(remove_data['EndDate_y'])

# Calculate the career duration in years
remove_data['career_duration'] = (remove_data['EndDate_y'] - remove_data['BeginDate_y']).dt.days / 365.25

# Create a histogram for career duration
plt.figure(figsize=(10, 6))
ax = sns.histplot(remove_data['career_duration'].dropna(), kde=True, bins=30, color='skyblue')

# Set x-axis labels to display in integer format
ax.xaxis.set_major_locator(plt.MaxNLocator(integer=True))

# Add labels and title
plt.title('Distribution of Artist Career Durations')
plt.xlabel('Career Duration (years)')
plt.ylabel('Frequency')

# Display the plot
plt.show()

# %% [markdown]
# ### <span style="color:green">***Artists Analyzing on the begin date***</span>

# %%
unique_begin_dates = remove_data['BeginDate_y'].unique()

print("Unique Begin Dates:", unique_begin_dates)

# Plot a histogram of 'BeginDate_y' with a specified range
plt.figure(figsize=(12, 6))
plt.hist(remove_data['BeginDate_y'], bins=range(1800, 2021, 1), edgecolor='black')  # Adjust the range as needed
plt.title('Distribution of Begin Dates')
plt.xlabel('Begin Date')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better visibility
plt.show()
# Out:
# Unique Begin Dates: [1841 1944 1876 1901 1878 1869 1933 1949 1934 1886 1885 1947 1887 1919
#  1918 1936 1950 1928 1867 1935 1943 1941 1931 1957 1895 1909 1900 1946
#  1956 1927 1951 1890 1939 1929 1926 1962 1883 1889 1959 1915 1892 1955
#     0 1938 1932 1923 1930 1937 1917 1967 1925 1898 1963 1906 1971 1945
#  1987 1976 1920 1908 1911 1870 1851 1924 1907 1916 1903 1914 1904 1879
#  1958 1896 1868 1897 1893 1902 1969 1970 1952 1874 1894 1891 1853 1921
#  1899 1913 1881 1910 1961 1953 1940 1905 1848 1846 1875 1852 1833 1871
#  1948 1954 1855 1858 1888 1966 1850 1826 1814 1960 1840 1968 1843 1808
#  1834 1802 1912 1942 1964 1765 1880 1974 1730 1873 1860 1731 1818 1772
#  1821 1865 1965 1983 1863 1922 1866 1864 1856 1857 1972 1979 1847 1796
#  2000 1837 1882 1884 1981 1999 1872 1836 1859 1992 1825 1842 1877 1854
#  1861 1862 1993 1977 1978 1839 1753 1792 1798 1832 1746 1819 1817 1827
#  1844 1835 1849 1845 1800 1830 1797 1829 1820 1816 1815 1823 1822 1831
# ...

# %% [markdown]
# #### The histogram visually represents the distribution of artists across historical periods in the dataset. The peaks and valleys in the histogram suggest varying levels of artistic activity during different historical eras. Notably, 1850 stands out with a higher frequency of artists, indicating a concentrated period of creative output. Conversely, 1900-1950 shows a comparatively lower frequency, suggesting a potential lull in artistic contributions. This visualization provides a temporal perspective on the dataset, allowing for a nuanced understanding of the ebb and flow of artistic activity over different historical epochs

# %% [markdown]
# ### <span style="color:green">***Artists across Historical Periods***</span>

# %%
plt.figure(figsize=(12, 6))

# Create a histogram for the distribution of artists across historical periods
sns.histplot(x='Date', data=remove_data, kde=True, color='skyblue')
plt.title('Distribution of Artists across Historical Periods')
plt.xlabel('Historical Period')
plt.ylabel('Frequency')

plt.show()

# %% [markdown]
# #### The histogram visually represents the distribution of artists' begin dates in the dataset. The chart provides insights into the temporal distribution of artists' career initiations, revealing a diverse range of begin dates spanning several centuries. Notably, there is a concentration of artist entries during specific periods, such as 1960-2000, indicating heightened artistic activity. The histogram effectively captures the historical evolution of artists' careers, offering a comprehensive overview of their beginnings over time.
