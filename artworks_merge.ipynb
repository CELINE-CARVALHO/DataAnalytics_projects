# %%
import pandas as pd
df1 = pd.read_csv("Artworks.csv")
df2 = pd.read_csv("Artists.csv")

# %%
import pandas
filenames = ["Artworks.csv", "Artists.csv"] 
df = pandas.DataFrame()
for filename in filenames:
    df = df.append(pandas.read_csv("append_file"))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16736\108812396.py in ?()
#       1 import pandas
#       2 filenames = ["Artworks.csv", "Artists.csv"]
#       3 df = pandas.DataFrame()
#       4 for filename in filenames:
# ----> 5     df = df.append(pandas.read_csv("append_file"))
#
# ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6200             and name not in self._accessors
#    6201             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %%
import pandas as pd


df1 = pd.read_csv("Artworks.csv")
df2 = pd.read_csv("Artists.csv")


combined_df = pd.concat([df1, df2])


combined_df.to_csv('combined_files.csv')

# %%
combined_df.head()
# Out:
#                                                Title  \
# 0  Ferdinandsbrücke Project, Vienna, Austria (Ele...
# 1  City of Music, National Superior Conservatory ...
# 2  Villa near Vienna Project, Outside Vienna, Aus...
# 3  The Manhattan Transcripts Project, New York, N...
# 4  Villa, project, outside Vienna, Austria, Exter...
#
#                      Artist ConstituentID  \
# 0               Otto Wagner          6210
# 1  Christian de Portzamparc          7470
# 2                Emil Hoppe          7605
# 3           Bernard Tschumi          7056
# 4                Emil Hoppe          7605
#
#                                    ArtistBio Nationality BeginDate EndDate  \
# 0                      (Austrian, 1841–1918)  (Austrian)    (1841)  (1918)
# 1                        (French, born 1944)    (French)    (1944)     (0)
# 2                      (Austrian, 1876–1957)  (Austrian)    (1876)  (1957)
# 3  (French and Swiss, born Switzerland 1944)          ()    (1944)     (0)
# ...

# %%
import pandas as pd
df = pd.read_csv('combined_df')
artists_after_1940 = df.loc[df['Year'] > 1940, 'Artist']
print(artists_after_1940)

# %%
combined_df.loc[(combined_df.Nationality == "American")]
# Out:
#       Title Artist ConstituentID                      ArtistBio Nationality  \
# 0       NaN    NaN             1            American, 1930–1992    American
# 2       NaN    NaN             3            American, born 1941    American
# 3       NaN    NaN             4            American, born 1946    American
# 6       NaN    NaN             7            American, born 1941    American
# 7       NaN    NaN             9  American, born Lithuania 1923    American
# ...     ...    ...           ...                            ...         ...
# 15230   NaN    NaN        134780            American, 1825–1910    American
# 15231   NaN    NaN        134781            American, 1834–1884    American
# 15233   NaN    NaN        134819            American, born 1987    American
# 15239   NaN    NaN        135032          American, 1942 – 2021    American
# 15242   NaN    NaN        135298            American, 1919–2012    American
#
# ...

# %%
combined_df.iloc[1:5, 2:5]  #[rows,columns]
# Out:
#   ConstituentID                                  ArtistBio Nationality
# 1          7470                        (French, born 1944)    (French)
# 2          7605                      (Austrian, 1876–1957)  (Austrian)
# 3          7056  (French and Swiss, born Switzerland 1944)          ()
# 4          7605                      (Austrian, 1876–1957)  (Austrian)
